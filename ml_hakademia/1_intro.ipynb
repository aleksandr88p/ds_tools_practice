# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('listings.csv')

# %%
df.head()
# Out:
#       id                                           name  host_id  \
# 0   3176                Fabulous Flat in great Location     3718
# 1   9991            Geourgeous flat - outstanding views    33852
# 2  14325            Studio Apartment in Prenzlauer Berg    55531
# 3  16644             In the Heart of Berlin - Kreuzberg    64696
# 4  17904  Beautiful Kreuzberg studio - 3 months minimum    68997
#
#         host_name       neighbourhood_group             neighbourhood  \
# 0          Britta                    Pankow   Prenzlauer Berg Südwest
# 1         Philipp                    Pankow   Prenzlauer Berg Südwest
# 2  Chris + Oliver                    Pankow  Prenzlauer Berg Nordwest
# 3            Rene  Friedrichshain-Kreuzberg     nördliche Luisenstadt
# 4        Matthias                  Neukölln              Reuterstraße
#
#    latitude  longitude        room_type  price  minimum_nights  \
# 0  52.53471   13.41810  Entire home/apt  105.0              63
# 1  52.53269   13.41805  Entire home/apt  180.0               6
# 2  52.54813   13.40366  Entire home/apt   70.0             150
# 3  52.50312   13.43508  Entire home/apt   90.0              93
# 4  52.49419   13.42166  Entire home/apt   25.0              92
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                148  2023-05-25               0.81
# 1                  7  2020-01-04               0.06
# 2                 26  2023-11-30               0.15
# 3                 48  2017-12-14               0.28
# 4                299  2022-12-01               1.71
#
#    calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                               1               272                      0
# 1                               1                32                      0
# 2                               4               185                      1
# 3                               2                 0                      0
# 4                               1                 1                      0
#
#                                              license
# 0  First name and Last name: Nicolas Krotz <br/> ...
# 1                                  03/Z/RA/003410-18
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df = pd.get_dummies(df,columns=['neighbourhood_group','neighbourhood'])

df.head()
# Out:
#       id                                           name  host_id  \
# 0   3176                Fabulous Flat in great Location     3718
# 1   9991            Geourgeous flat - outstanding views    33852
# 2  14325            Studio Apartment in Prenzlauer Berg    55531
# 3  16644             In the Heart of Berlin - Kreuzberg    64696
# 4  17904  Beautiful Kreuzberg studio - 3 months minimum    68997
#
#         host_name  latitude  longitude        room_type  price  \
# 0          Britta  52.53471   13.41810  Entire home/apt  105.0
# 1         Philipp  52.53269   13.41805  Entire home/apt  180.0
# 2  Chris + Oliver  52.54813   13.40366  Entire home/apt   70.0
# 3            Rene  52.50312   13.43508  Entire home/apt   90.0
# 4        Matthias  52.49419   13.42166  Entire home/apt   25.0
#
#    minimum_nights  number_of_reviews  ... neighbourhood_West 3  \
# 0              63                148  ...                False
# 1               6                  7  ...                False
# 2             150                 26  ...                False
# 3              93                 48  ...                False
# 4              92                299  ...                False
#
#    neighbourhood_West 4  neighbourhood_West 5  neighbourhood_Westend  \
# 0                 False                 False                  False
# 1                 False                 False                  False
# 2                 False                 False                  False
# 3                 False                 False                  False
# 4                 False                 False                  False
#
#    neighbourhood_Wiesbadener Straße neighbourhood_Wilhelmstadt  \
# 0                             False                      False
# 1                             False                      False
# 2                             False                      False
# 3                             False                      False
# 4                             False                      False
#
#    neighbourhood_Zehlendorf  Nord  neighbourhood_Zehlendorf  Südwest  \
# 0                           False                              False
# 1                           False                              False
# 2                           False                              False
# 3                           False                              False
# 4                           False                              False
#
#    neighbourhood_nördliche Luisenstadt  neighbourhood_südliche Luisenstadt
# 0                                False                               False
# 1                                False                               False
# 2                                False                               False
# 3                                 True                               False
# 4                                False                               False
#
# [5 rows x 166 columns]

# %%
df = pd.get_dummies(df, columns = ['neighbourhood_group', 'neighbourhood'], drop_first = True)
df.head()
# Out:
#       id                                           name  host_id  \
# 0   3176                Fabulous Flat in great Location     3718
# 1   9991            Geourgeous flat - outstanding views    33852
# 2  14325            Studio Apartment in Prenzlauer Berg    55531
# 3  16644             In the Heart of Berlin - Kreuzberg    64696
# 4  17904  Beautiful Kreuzberg studio - 3 months minimum    68997
#
#         host_name  latitude  longitude        room_type  price  \
# 0          Britta  52.53471   13.41810  Entire home/apt  105.0
# 1         Philipp  52.53269   13.41805  Entire home/apt  180.0
# 2  Chris + Oliver  52.54813   13.40366  Entire home/apt   70.0
# 3            Rene  52.50312   13.43508  Entire home/apt   90.0
# 4        Matthias  52.49419   13.42166  Entire home/apt   25.0
#
#    minimum_nights  number_of_reviews  ... neighbourhood_West 3  \
# 0              63                148  ...                False
# 1               6                  7  ...                False
# 2             150                 26  ...                False
# 3              93                 48  ...                False
# 4              92                299  ...                False
#
#    neighbourhood_West 4  neighbourhood_West 5  neighbourhood_Westend  \
# 0                 False                 False                  False
# 1                 False                 False                  False
# 2                 False                 False                  False
# 3                 False                 False                  False
# 4                 False                 False                  False
#
#    neighbourhood_Wiesbadener Straße neighbourhood_Wilhelmstadt  \
# 0                             False                      False
# 1                             False                      False
# 2                             False                      False
# 3                             False                      False
# 4                             False                      False
#
#    neighbourhood_Zehlendorf  Nord  neighbourhood_Zehlendorf  Südwest  \
# 0                           False                              False
# 1                           False                              False
# 2                           False                              False
# 3                           False                              False
# 4                           False                              False
#
#    neighbourhood_nördliche Luisenstadt  neighbourhood_südliche Luisenstadt
# 0                                False                               False
# 1                                False                               False
# 2                                False                               False
# 3                                 True                               False
# 4                                False                               False
#
# [5 rows x 164 columns]

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 164

# %%
# check for missing values
df['reviews_per_month'].isnull().sum()
# Out:
# 0

# %%
# check length of dataframe
len(df)
# Out:
# 13759

# %%
# fill missing values with the mean
df['reviews_per_month'].fillna((df['reviews_per_month'].mean()), inplace=True)

# %%
# check if there are any missing values
df['reviews_per_month'].isnull().sum()
# Out:
# 0
